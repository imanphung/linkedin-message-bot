# %%
import os, random, sys, time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

# %%
file = open('login.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

# %%
link = 'https://www.linkedin.com/uas/login'
file = open('messages.txt')
customMessage = file.read()
file1 = open('subject.txt')
subject = file1.read()
print('Subject: ' + subject)
print('Messages: ' + customMessage)
data = pd.read_csv("data.csv")
data[:]
# Out:
# Subject: Invitation
# Messages: This is Henry Duong, Founder of Global QT-Group with the following two advanced competitive features:
# QT-AI (global TradeMark) improves 30% operational productivity.
# QT-Invest (global TradeMark) improves 20% financial productivity.
# Let's connect and have a good collaboration!
#     name                                      linkedin_link  facebook_link
# 0    NaN          https://www.linkedin.com/in/fergalmullen/            NaN
# 1    NaN  https://www.linkedin.com/in/forest-baskett-a58...            NaN
# 2    NaN  https://www.linkedin.com/in/peter-barris-7a440...            NaN
# 3    NaN            https://www.linkedin.com/in/arnondinur/            NaN
# 4    NaN        https://www.linkedin.com/in/schwenderheiko/            NaN
# 5    NaN  https://www.linkedin.com/in/patrickmeisberger/...            NaN
# 6    NaN  https://www.linkedin.com/in/phuong-lan-dao-651...            NaN
# 7    NaN  https://www.linkedin.com/in/jim-armstrong-2a7702/            NaN
# 8    NaN          https://www.linkedin.com/in/sumantmandal/            NaN
# 9    NaN             https://www.linkedin.com/in/suaadsait/            NaN
# 10   NaN           https://www.linkedin.com/in/marksiegel2/            NaN
# 11   NaN            https://www.linkedin.com/in/meganquinn/            NaN
# 12   NaN           https://www.linkedin.com/in/santopoliti/            NaN
# 13   NaN           https://www.linkedin.com/in/lukewalling/            NaN
# 14   NaN          https://www.linkedin.com/in/themikewalsh/            NaN
# 15   NaN               https://www.linkedin.com/in/chandna/            NaN
# 16   NaN                https://www.linkedin.com/in/oahzrh/            NaN
# 17   NaN             https://www.linkedin.com/in/manugupta/            NaN
# 18   NaN            https://www.linkedin.com/in/daneldayan/            NaN
# 19   NaN  https://www.linkedin.com/in/russell-fleischer-...            NaN

# %%
def check_exists_by_class(_class):
    try:
        browser.find_element_by_class_name(_class)
    except NoSuchElementException:
        return False
    return True

def check_exists_by_path(_path):
    try:
        browser.find_element_by_xpath(_path)
    except NoSuchElementException:
        return False
    return True

# %%
#Open link on chrome
browser = webdriver.Chrome('driver/chromedriver.exe')
browser.get(link)
time.sleep(random.uniform(3, 7))

#Access account
elementID = browser.find_element_by_id('username')
elementID.send_keys(username)
elementID = browser.find_element_by_id('password')
elementID.send_keys(password)
elementID.submit()
# time.sleep(random.uniform(3, 7))
print('Login to Linkedin')

#Open file visitedUsers 
visitedUsers = pd.read_csv('visited_user.csv')
print('LinkedinBot: START')
for _,row in data.iterrows():
    try:
        full_link = row['linkedin_link']
        if full_link in visitedUsers.values:
            for _,rowVisited in visitedUsers.iterrows():
                if rowVisited['link'] in full_link:
                    if rowVisited['status'] in 'error':
                        print('Error: ', full_link)
                    elif rowVisited['status'] in 'done':
                        print('Already sent to: ', full_link)
                    else:
                        print(rowVisited['status'], full_link)
                    break
        else:
            #Send message
            browser.get(full_link)
            time.sleep(random.uniform(3, 7))

            #Connect
            checkProfileActions = browser.find_element_by_class_name('pv-s-profile-actions')
            if 'pv-s-profile-actions--connect' in checkProfileActions.get_attribute('class').split():
                browser.find_element_by_class_name('pv-s-profile-actions--connect').click()
                browser.find_element_by_xpath("//button[contains(@aria-label, 'Add a note')]").click()
                browser.find_element_by_id('custom-message').send_keys(customMessage)
                checkSentButton = browser.find_element_by_class_name('ml1')
                if 'artdeco-button--disabled' in checkSentButton.get_attribute('class').split():
                    browser.find_element_by_class_name('artdeco-modal__dismiss').click()
                    browser.find_element_by_class_name('pv-s-profile-actions--message').click()
                    time.sleep(random.uniform(3, 5))
                    if True == check_exists_by_class('msg-form__subject'):
                        browser.find_element_by_class_name('msg-form__subject').send_keys(subject)
                    if True == check_exists_by_class('msg-form__contenteditable'):
                        browser.find_element_by_class_name('msg-form__contenteditable').send_keys(customMessage)
                    time.sleep(random.uniform(2, 3))
                    if True == check_exists_by_class('msg-form__send-button'):
                        browser.find_element_by_class_name('msg-form__send-button').click()
                else:
                    checkSentButton.click()
                    
            # Follow
            elif 'pv-s-profile-actions--follow' in checkProfileActions.get_attribute('class').split():
                browser.find_element_by_class_name('pv-s-profile-actions--follow').click()
                time.sleep(random.uniform(2, 4))
                browser.find_element_by_class_name('pv-s-profile-actions__overflow-toggle').click()
                browser.find_element_by_class_name('pv-s-profile-actions--connect').click()
                time.sleep(random.uniform(3, 7))
                browser.find_element_by_xpath("//button[contains(@aria-label, 'Add a note')]").click()
                browser.find_element_by_id('custom-message').send_keys(customMessage)
                browser.find_element_by_class_name('ml1').click()

            print(full_link, ': sent')
            visitedUsers = visitedUsers.append({'link':full_link, 'status':'done'}, ignore_index = True)
            visitedUsers.to_csv('visited_user.csv',index=False) 
            # Otherwise, sleep to make sure everything loads
            time.sleep(random.uniform(3, 7))
            
    except: 
        visitedUsers = visitedUsers
        
        visitedUsers.to_csv('visited_user.csv',index=False) 
        
print('LinkedinBot: DONE!')
# Out:
# Login to Linkedin
# LinkedinBot: START
# Already sent to:  https://www.linkedin.com/in/fergalmullen/
# Already sent to:  https://www.linkedin.com/in/forest-baskett-a5813413/
# Already sent to:  https://www.linkedin.com/in/peter-barris-7a44011b/
# Already sent to:  https://www.linkedin.com/in/arnondinur/
# Already sent to:  https://www.linkedin.com/in/schwenderheiko/
# Already sent to:  https://www.linkedin.com/in/patrickmeisberger/?originalSubdomain=de
# Already sent to:  https://www.linkedin.com/in/phuong-lan-dao-651503/
# Already sent to:  https://www.linkedin.com/in/jim-armstrong-2a7702/
# Already sent to:  https://www.linkedin.com/in/sumantmandal/
# Already sent to:  https://www.linkedin.com/in/suaadsait/
# Already sent to:  https://www.linkedin.com/in/marksiegel2/
# Already sent to:  https://www.linkedin.com/in/meganquinn/
# Error:  https://www.linkedin.com/in/santopoliti/
# Already sent to:  https://www.linkedin.com/in/lukewalling/
# Already sent to:  https://www.linkedin.com/in/themikewalsh/
# Already sent to:  https://www.linkedin.com/in/chandna/
# Already sent to:  https://www.linkedin.com/in/oahzrh/
# Already sent to:  https://www.linkedin.com/in/manugupta/
# Already sent to:  https://www.linkedin.com/in/daneldayan/
# Already sent to:  https://www.linkedin.com/in/russell-fleischer-37333934/
# LinkedinBot: DONE!
